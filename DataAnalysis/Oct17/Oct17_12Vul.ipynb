# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.modeling import models, fitting
fitter = fitting.LinearLSQFitter()
from scipy.ndimage import median_filter

# %%
fname = '../../DataReduction/FullSes17Oct12Vul_20241018T014344.fit'

# %%
fits.getheader(fname)
# Out:
# SIMPLE  =                    T
# BITPIX  =                  -32 / bits per data value
# NAXIS   =                    1 / Number of data axes
# NAXIS1  =                88319 / Length of data axis 1
# EXPTIME =                  300 / [s] Total observation duration
# DATE-OBS= '2024-10-18T01:41:14.705' / Date of observation start
# BSCALE  =                    1 / linear factor in scaling equation
# BZERO   =                    0 / zero point in scaling equation
# EXPOSURE=                  300 / [s] Total time of exposure
# EXPTIME2= '1 x 300 s' / Exposure decomposition
# JD-OBS  =   2460601.5702999998 / JD start observation
# JD-MID  =   2460601.5720000002 / JD mid observation
# CRPIX1  =                    1 / Pixel start
# CTYPE1  = 'Wavelength' / Axis 1 description
# CUNIT1  = 'Angstrom' / Axis 1 unit
# BSS_ITRP=                10000 / Instrument Typical Resolving Power (Indicative)
# DATAMIN =  0.59944632826809918 / [adu] minimum value for all pixels
# ...

# %%
b = fits.getval(fname,"CRVAL1")
m = fits.getval(fname,"CDELT1")

# %%
y = fits.getdata(fname)

# %%
x = m*np.arange(len(y))+b

# %%
plt.plot(x,y)

plt.xlim(6400,6600)
plt.ylim(0,5)
# Out:
# (0.0, 5.0)

# %%
y = fits.getdata(fname)
y_new=y.tolist()
y_filt=median_filter(y_new,200)
x = m*np.arange(len(y))+b

mask_alpha=np.abs(6562.8-x)>40
mask_beta=np.abs(4861.33333333333-x)>40
mask_gamma=np.abs(4367.23-x)>50 #H_gamma está corrido
mask=mask_alpha&mask_beta&mask_gamma

# %%
plt.figure(figsize=(15,5))
plt.plot(x[mask],y_filt[mask])

plt.plot(x,y_filt)

#plt.axvline(4367.23)

#plt.xlim(4000,4800)
#plt.ylim(0,5)

# %%
modelo = fitter(models.Chebyshev1D(25),x[mask],y_filt[mask])

# %%
plt.figure(figsize=(15,5))
plt.plot(x,y)
#plt.plot(x,y_filt)
plt.plot(x,modelo(x),c='k')


plt.xlim(6400,6600)
plt.ylim(0,5)
plt.margins(x=0)

# %%
plt.figure(figsize=(15,5))
plt.scatter(x,y_filt-modelo(x),c='k',s=1,alpha=0.5)
plt.xlim(6400,6700)
plt.ylim(-1,1)
# Out:
# (-1.0, 1.0)
